# %% [markdown]
# ## Original Dataset:
# https://www.eia.gov/environment/emissions/state/excel/electricity.xlsx

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("annual_electricity_related_CO2_emissions.csv")

# %%
df.head()
# Out:
#   Electricity Emissions by State (1980 - 2018) Unnamed: 1 Unnamed: 2  \
# 0        million metric tons of carbon dioxide        NaN        NaN
# 1                                        State       1980       1981
# 2                                      Alabama       44.1       44.1
# 3                                       Alaska        2.3        2.4
# 4                                      Arizona       25.3       31.1
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1       1982       1983       1984       1985       1986       1987
# 2       35.3       38.8       40.3       48.9       49.1       47.8
# 3        2.6        2.6        2.6        2.7        2.7        2.4
# 4       30.6       26.3       28.8       31.0       25.3       27.0
#
#   Unnamed: 9  ... Unnamed: 32 Unnamed: 33 Unnamed: 34 Unnamed: 35 Unnamed: 36  \
# ...

# %%
df.columns = df.iloc[1]

# %%
df.head()
# Out:
# 1                                  State  1980  1981  1982  1983  1984  1985  \
# 0  million metric tons of carbon dioxide   NaN   NaN   NaN   NaN   NaN   NaN
# 1                                  State  1980  1981  1982  1983  1984  1985
# 2                                Alabama  44.1  44.1  35.3  38.8  40.3  48.9
# 3                                 Alaska   2.3   2.4   2.6   2.6   2.6   2.7
# 4                                Arizona  25.3  31.1  30.6  26.3  28.8  31.0
#
# 1  1986  1987  1988  ...  2011  2012  2013  2014  2015  2016  2017  2018  \
# 0   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  1986  1987  1988  ...  2011  2012  2013  2014  2015  2016  2017  2018
# 2  49.1  47.8  46.0  ...  74.6  67.0  64.7  65.6  62.4  55.6  51.0  53.9
# 3   2.7   2.4   2.4  ...   3.2   3.1   2.6   2.9   3.0   2.8   2.8   2.7
# 4  25.3  27.0  29.4  ...  52.8  51.8  55.2  53.6  50.1  44.6  43.8  46.8
#
# 1                  Percent  Absolute
# ...

# %%
states = ["California", "Colorado", "Connecticut", "Florida", "Montana", "Michigan", "Minnesota", "New Jersey", "New York", "Oregon", "Tennessee", "Texas", "Vermont", "Virginia", "Washington", "Wisconsin"]

# %%
new_df = df.loc[(df["State"].isin(states))]

# %%
new_df
# Out:
# 1         State   1980   1981   1982   1983   1984   1985   1986   1987  \
# 6    California   61.1   59.4   37.8   31.4   34.3   39.6   27.4   37.2
# 7      Colorado   20.8   23.0   23.7   22.6   25.3   26.5   26.3   26.7
# 8   Connecticut   10.7    9.1    8.6    9.8   10.3   10.5   11.1   10.1
# 11      Florida   64.5   68.2   58.4   62.7   58.7   62.6   72.1   78.7
# 24     Michigan   56.0   55.2   50.6   51.0   54.6   57.7   60.6   68.1
# 25    Minnesota   21.4   21.1   18.1   18.0   19.7   19.0   16.8   22.5
# 28      Montana    5.6    5.5    4.2    3.7    8.2    9.0   12.0   12.2
# 32   New Jersey   18.2   16.7   14.7   17.3   16.9   14.8   13.1   14.5
# 34     New York   53.7   53.2   51.7   51.9   50.9   49.7   48.8   54.2
# 39       Oregon    0.8    1.9    0.8    0.6    0.8    0.7    0.0    0.0
# 44    Tennessee   47.5   44.8   36.8   41.5   42.5   46.5   47.2   46.7
# 45        Texas  142.4  147.9  151.1  155.8  161.9  166.6  163.6  165.5
# ...

# %%
remyears = []
for i in range(1980,2011):
    remyears.append(i)

# %%
rem = []
for year in remyears:
    rem.append(str(year))
rem
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010']

# %%
new_df.drop(columns=rem, inplace=True)
# Out:
# /var/folders/4f/n3zjdg6d20g0v9p26cnqg5tm0000gn/T/ipykernel_3292/3964668915.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop(columns=rem, inplace=True)

# %%
new_df.drop(columns=["Percent", "Absolute"], inplace=True)
# Out:
# /var/folders/4f/n3zjdg6d20g0v9p26cnqg5tm0000gn/T/ipykernel_3292/755820809.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop(columns=["Percent", "Absolute"], inplace=True)

# %%
new_df
# Out:
# 1         State   2011   2012   2013   2014   2015   2016   2017   2018
# 6    California   36.4   48.0   45.7   46.3   44.3   36.6   33.0   33.7
# 7      Colorado   39.3   39.5   39.0   38.1   37.0   35.7   35.2   34.2
# 8   Connecticut    6.6    7.2    6.8    6.7    7.4    7.0    6.3    8.1
# 11      Florida  111.0  107.5  105.2  109.8  108.1  106.4  103.4  100.9
# 24     Michigan   65.6   63.5   62.7   60.2   63.0   55.6   55.7   58.9
# 25    Minnesota   29.3   25.7   26.0   29.4   27.2   26.7   25.3   26.7
# 28      Montana   16.7   15.7   16.6   17.3   17.8   16.1   15.5   15.1
# 32   New Jersey   15.7   14.9   14.4   16.8   17.9   19.7   16.7   17.4
# 34     New York   33.9   32.3   30.1   30.6   29.2   27.8   22.1   24.5
# 39       Oregon    6.4    7.0    9.1    8.0    8.6    7.8    7.5    8.4
# 44    Tennessee   41.0   37.7   33.9   37.5   33.9   36.2   32.3   26.1
# 45        Texas  239.5  223.7  227.9  226.5  215.1  209.0  212.5  202.3
# ...

# %%
new_df.reset_index(drop=True, inplace=True)

# %%
new_df
# Out:
# 1         State   2011   2012   2013   2014   2015   2016   2017   2018
# 0    California   36.4   48.0   45.7   46.3   44.3   36.6   33.0   33.7
# 1      Colorado   39.3   39.5   39.0   38.1   37.0   35.7   35.2   34.2
# 2   Connecticut    6.6    7.2    6.8    6.7    7.4    7.0    6.3    8.1
# 3       Florida  111.0  107.5  105.2  109.8  108.1  106.4  103.4  100.9
# 4      Michigan   65.6   63.5   62.7   60.2   63.0   55.6   55.7   58.9
# 5     Minnesota   29.3   25.7   26.0   29.4   27.2   26.7   25.3   26.7
# 6       Montana   16.7   15.7   16.6   17.3   17.8   16.1   15.5   15.1
# 7    New Jersey   15.7   14.9   14.4   16.8   17.9   19.7   16.7   17.4
# 8      New York   33.9   32.3   30.1   30.6   29.2   27.8   22.1   24.5
# 9        Oregon    6.4    7.0    9.1    8.0    8.6    7.8    7.5    8.4
# 10    Tennessee   41.0   37.7   33.9   37.5   33.9   36.2   32.3   26.1
# 11        Texas  239.5  223.7  227.9  226.5  215.1  209.0  212.5  202.3
# ...
